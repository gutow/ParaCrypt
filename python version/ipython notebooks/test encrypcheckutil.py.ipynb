# %%
from encrypcheckutil import *
from scipy.stats import chisquare as chisq

# %%
values = slurpfilebytesasarray('/home/jonathan/git/GoodSymCrypt/tests/Encrypt test document.odt')
# Out:
# Reading file: /home/jonathan/git/GoodSymCrypt/tests/Encrypt test document.odt
# File size: 33938

# %%
print (str(len(values)))
# Out:
# 33938

# %%
x,y = rmsdevautocorr(values)

# %%
import matplotlib.pyplot as plt
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.axis([-1,512,90,max(y)*1.01])
plt.show()

# %%
popt,cov = fit_to_exp(x[1:512],y[1:512], verbose=True)
# Out:
# Start: 458 Stop: 510
# guessy0 :107.61411572
# guessA: -8.38085028533
# guesstau: 31.538898097
# fit: y=107.276812294+-5.63625345682*exp(-x/390.71732419)
# covariance;[[  1.04186219e-03  -9.01671764e-04   1.27428311e-01]
#  [ -9.01671764e-04   5.63454075e-03   7.09369526e-01]
#  [  1.27428311e-01   7.09369526e-01   2.29870035e+02]]

# %%
fit = exp_for_fit(x,popt[0],popt[1],popt[2])
plt.plot(x,y,'.')
print('chisq of point 1 onward:'+str(chisq(y[1:512],fit[1:512])))
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(x,fit,'.')
plt.show()
# Out:
# chisq of point 1 onward:Power_divergenceResult(statistic=1.1976240291934954, pvalue=1.0)

# %%
popt,cov = fit_to_gauss(x,y,verbose=True)
fit = gauss_for_fit(x,popt[0],popt[1],popt[2])
print('chisq of point 1 onward:'+str(chisq(y[1:512],fit[1:512])))
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(x,fit,'.')
plt.show()
# Out:
# Start: 459 Stop: 511
# guessy0 :107.61411572
# guessA: -107.61411572
# guesstau: 0.625904982948
# fit: y=105.170099204+-105.169933435*exp(-(x/0.589896813231)**2)
# covariance;[[  9.14383037e-03  -9.14355100e-03   1.49141533e-04]
#  [ -9.14355100e-03   4.67248417e+00   4.40251352e-03]
#  [  1.49141533e-04   4.40251352e-03   1.39840320e-03]]
# chisq of point 1 onward:Power_divergenceResult(statistic=22.569540459027891, pvalue=1.0)

# %%
popt,cov = fit_to_gauss(x[1:512],y[1:512],verbose=True)
fit = gauss_for_fit(x,popt[0],popt[1],popt[2])
print('chisq of point 1 onward:'+str(chisq(y[1:512],fit[1:512])))
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(x,fit,'.')
plt.show()
# Out:
# Start: 458 Stop: 510
# guessy0 :107.61411572
# guessA: -8.38085028533
# guesstau: 7.94215312078
# fit: y=107.237447025+-4.89572596222*exp(-(x/337.279594884)**2)
# covariance;[[  1.35867354e-03  -1.31290991e-03   6.64964171e-02]
#  [ -1.31290991e-03   4.62243671e-03   3.05409574e-01]
#  [  6.64964171e-02   3.05409574e-01   9.21815299e+01]]
# chisq of point 1 onward:Power_divergenceResult(statistic=1.6343608964909349, pvalue=1.0)

# %%
popt,cov = fit_to_line(x[1:512],y[1:512],verbose=True)
fit = line_for_fit(x,popt[0],popt[1])
print('chisq of point 1 onward:'+str(chisq(y[1:512],fit[1:512])))
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(x,fit,'.')
plt.show()
# Out:
# Start: 458 Stop: 510
# bguess :102.449639788
# mguess: 0.00048212551399
# fit: y=103.779571107+0.000323334308151*x
# covariance;[[  5.53809745e-03  -5.04726278e-07]
#  [ -5.04726278e-07   1.18351767e-10]]
# chisq of point 1 onward:Power_divergenceResult(statistic=8.4019488302512038, pvalue=1.0)

# %%
values = slurpfilebytesasarray('/home/jonathan/git/GoodSymCrypt/test_vg.ecr')
x,y = rmsdevautocorr(values)
popt,cov = fit_to_exp(x[1:512],y[1:512],verbose=True)
fit = exp_for_fit(x,popt[0],popt[1],popt[2])
print('chisq of point 1 onward:'+str(chisq(y[1:512],fit[1:512])))
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(x,fit,'.')
plt.show()
# Out:
# Reading file: /home/jonathan/git/GoodSymCrypt/test_vg.ecr
# File size: 67968
# /home/jonathan/git/GoodSymCrypt/encrypcheckutil.py:11: RuntimeWarning: overflow encountered in exp
#   y[i]=(y0+A*exp(-x[i]/tau))
# Start: 458 Stop: 510
# guessy0 :103.721393044
# guessA: -0.142342113376
# guesstau: 3.20315446241
# fit: y=103.675471542+-499.320662983*exp(-x/0.116900663608)
# covariance;[[  8.60534562e-05   2.06283392e+03   5.99619364e-02]
#  [  2.06283392e+03   2.52395393e+13   7.33505408e+08]
#  [  5.99619364e-02   7.33505408e+08   2.13169583e+04]]
# chisq of point 1 onward:Power_divergenceResult(statistic=0.21462177947986782, pvalue=1.0)

# %%
popt,cov = fit_to_exp(x,y,verbose=True)
fit = exp_for_fit(x,popt[0],popt[1],popt[2])
print('chisq of point 1 onward:'+str(chisq(y[1:512],fit[1:512])))
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(x,fit,'.')
plt.show()
# Out:
# Start: 459 Stop: 511
# guessy0 :103.723471289
# guessA: -103.723471289
# guesstau: 0.152050657753
# fit: y=103.669488229+-103.669488326*exp(-x/0.14190875839)
# covariance;[[  8.38115171e-05  -8.38114536e-05   1.87033263e-05]
#  [ -8.38114536e-05   4.28273925e-02  -1.03963971e-05]
#  [  1.87033263e-05  -1.03963971e-05   2.12909629e-03]]
# chisq of point 1 onward:Power_divergenceResult(statistic=0.2098638956026222, pvalue=1.0)

# %%
popt,cov = fit_to_gauss(x,y,verbose=True)
fit = gauss_for_fit(x,popt[0],popt[1],popt[2])
print('chisq of point 1 onward:'+str(chisq(y[1:512],fit[1:512])))
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(x,fit,'.')
plt.show()
# Out:
# Start: 459 Stop: 511
# guessy0 :103.723471289
# guessA: -103.723471289
# guesstau: 0.389936735578
# fit: y=103.669488514+-103.669488514*exp(-(x/0.376774104368)**2)
# covariance;[[  8.38108644e-05  -8.38108644e-05   2.47163685e-05]
#  [ -8.38108644e-05   4.28273517e-02  -1.36844839e-05]
#  [  2.47163685e-05  -1.36844839e-05   3.73120049e-03]]
# chisq of point 1 onward:Power_divergenceResult(statistic=0.20986370026279999, pvalue=1.0)

# %%
popt,cov = fit_to_gauss(x[1:512],y[1:512],verbose=True)
fit = gauss_for_fit(x,popt[0],popt[1],popt[2])
print('chisq of point 1 onward:'+str(chisq(y[1:512],fit[0:511])))
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(x,fit,'.')
plt.show()
# Out:
# Start: 458 Stop: 510
# guessy0 :103.723471289
# guessA: -0.144420358696
# guesstau: 2.4497628685
# fit: y=103.669488477+-2.74180795438*exp(-(x/-0.541161370304)**2)
# covariance;[[  8.41408318e-05   1.85793177e+01  -5.86273500e-01]
#  [  1.85793177e+01   2.09301314e+09  -6.60368378e+07]
#  [ -5.86273500e-01  -6.60368378e+07   2.08353399e+06]]
# chisq of point 1 onward:Power_divergenceResult(statistic=0.27981695754081881, pvalue=1.0)

# %%
popt,cov = fit_to_line(x[1:512],y[1:512],verbose=True)
fit = line_for_fit(x,popt[0],popt[1])
print('chisq of point 1 onward:'+str(chisq(y[1:512],fit[1:512])))
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(x,fit,'.')
plt.show()
# Out:
# Start: 458 Stop: 510
# bguess :103.412416632
# mguess: -3.24860136077e-07
# fit: y=103.643480102+3.72803091075e-06*x
# covariance;[[  1.33495065e-04  -5.99172017e-09]
#  [ -5.99172017e-09   7.02368834e-13]]
# chisq of point 1 onward:Power_divergenceResult(statistic=0.2066838127183756, pvalue=1.0)

# %%
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(x,fit,'.')
plt.axis([-1,1024,102,max(y)*1.01])
plt.show()

# %%
values = slurpfilebytesasarray("/home/jonathan/git/GoodSymCrypt/Colin's new glasses.jpg")
x,y = rmsdevautocorr(values)
popt,cov = fit_to_line(x[1:512],y[1:512],verbose=True)
fit = line_for_fit(x,popt[0],popt[1])
print('chisq of point 1 onward:'+str(chisq(y[1:512],fit[1:512])))
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(x,fit,'.')
plt.show()
# Out:
# Reading file: /home/jonathan/git/GoodSymCrypt/Colin's new glasses.jpg
# File size: 511217
# Start: 458 Stop: 510
# bguess :103.676978246
# mguess: -1.02343613365e-06
# fit: y=103.759509822+1.92514685669e-06*x
# covariance;[[  8.60232450e-05  -5.04018732e-10]
#  [ -5.04018732e-10   7.81458067e-15]]
# chisq of point 1 onward:Power_divergenceResult(statistic=0.13402381819103457, pvalue=1.0)

# %%
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(x,fit,'.')
plt.axis([-1,258,102,max(y)*1.01])
plt.show()

# %%
popt,cov = fit_to_exp(x[1:512],y[1:512],verbose=True)
fit = exp_for_fit(x,popt[0],popt[1],popt[2])
print('chisq of point 1 onward:'+str(chisq(y[1:512],fit[1:512])))
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(x,fit,'.')
plt.axis([-1,258,102,max(y)*1.01])
plt.show()
# Out:
# /home/jonathan/git/GoodSymCrypt/encrypcheckutil.py:11: RuntimeWarning: overflow encountered in exp
#   y[i]=(y0+A*exp(-x[i]/tau))
# Start: 458 Stop: 510
# guessy0 :104.073823722
# guessA: 0.2766923122
# guesstau: 1.51277083991
# fit: y=103.882761122+30524.1178836*exp(-x/0.0902007958275)
# covariance;[[  1.03145041e-04   4.45013341e+05  -1.21453242e-01]
#  [  4.45013341e+05   9.79253429e+17  -2.67254330e+11]
#  [ -1.21453242e-01  -2.67254330e+11   7.29380922e+04]]
# chisq of point 1 onward:Power_divergenceResult(statistic=0.25673575708634577, pvalue=1.0)

# %%
popt,cov = fit_to_exp(x,y,verbose=True)
fit = exp_for_fit(x,popt[0],popt[1],popt[2])
print('chisq of point 1 onward:'+str(chisq(y[1:512],fit[1:512])))
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(x,fit,'.')
plt.axis([-1,258,102,max(y)*1.01])
plt.show()
# Out:
# /home/jonathan/git/GoodSymCrypt/encrypcheckutil.py:11: RuntimeWarning: overflow encountered in exp
#   y[i]=(y0+A*exp(-x[i]/tau))
# /usr/local/lib/python3.5/dist-packages/scipy/optimize/minpack.py:779: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Start: 459 Stop: 511
# guessy0 :104.073823722
# guessA: -104.073823722
# guesstau: 0.168635495428
# fit: y=103.883676456+-103.883676456*exp(-x/0.00239811177192)
# covariance;[[ inf  inf  inf]
#  [ inf  inf  inf]
#  [ inf  inf  inf]]
# chisq of point 1 onward:Power_divergenceResult(statistic=0.25883540766570523, pvalue=1.0)

# %%
def envelope(x,y):
    '''
    x       xdata
    y       ydata
    returns (upperenvx, upperenvy, lowerenvx, lowerenvy)
    Uses discrete (digital) derivatives to find local max and min. Maxes go into upperenv
      and min go into lowerenv. First and last points of the data set determine slopes, and
      are kept as part of the envelope, despite the fact that they might not be a max or min.
    '''
    size = len(x)
    upperenvx = np.empty(size)
    upperenvy = np.empty(size)
    lowerenvx = np.empty(size)
    lowerenvy = np.empty(size)
    upperenvx[0]=x[0]
    upperenvy[0]=y[0]
    lowerenvx[0]=x[0]
    lowerenvy[0]=y[0]
    uppercount = 1
    lowercount = 1
    for i in range(1,(size-1)):
        lslope = (y[i]-y[i-1])/(x[i]-x[i-1])
        rslope = (y[i+1]-y[i])/(x[i+1]-x[i])
        if (lslope*rslope < 0):
            if (rslope < 0):
                upperenvx[uppercount]=x[i]
                upperenvy[uppercount]=y[i]
                uppercount+=1
            else:
                lowerenvx[lowercount]=x[i]
                lowerenvy[lowercount]=y[i]
                lowercount+=1
    upperenvx[uppercount]=x[size-1]
    upperenvy[uppercount]=y[size-1]
    lowerenvx[lowercount]=x[size-1]
    lowerenvy[lowercount]=y[size-1]
    upperenvx.resize(uppercount+1)
    upperenvy.resize(uppercount+1)
    lowerenvx.resize(lowercount+1)
    lowerenvy.resize(lowercount+1)
    return(upperenvx, upperenvy, lowerenvx, lowerenvy)

def smoothenv(x,y,npass=2):
    '''
    x     xdata
    y     ydata
    npass number of passes with the envelope function to produce a smoothed envelope.
    returns (upperenvx, upperenvy, lowerenvx, lowerenvy)
    Uses discrete (digital) derivatives to find local max and min. Maxes go into upperenv
      and min go into lowerenv. First and last points of the data set determine slopes, and
      are kept as part of the envelope, despite the fact that they might not be a max or min.    
    '''
    upperenvx, upperenvy, lowerenvx, lowerenvy=envelope(x,y)
    for i in range(1,npass):
        #print ('Starting pass '+str(i)+'.')
        upperenvx, upperenvy, lowerupperx, loweruppery=envelope(upperenvx,upperenvy)
        upperlowerx, upperlowery, lowerenvx, lowerenvy=envelope(lowerenvx,lowerenvy)
    return (upperenvx, upperenvy, lowerenvx, lowerenvy)

# %%
upperenvx, upperenvy, lowerenvx, lowerenvy=envelope(x,y)
supperenvx, supperenvy, slowerenvx, slowerenvy=smoothenv(x,y)
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(upperenvx, upperenvy,'-')
plt.plot(lowerenvx, lowerenvy,'-')
plt.plot(supperenvx, supperenvy,'-')
plt.plot(slowerenvx, slowerenvy,'-')
plt.axis([-1,250,103,104.5])
plt.show()

# %%
popt,cov = fit_to_exp(slowerenvx[1:], slowerenvy[1:],verbose=True)
slowerfit = exp_for_fit(slowerenvx,popt[0],popt[1],popt[2])
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(supperenvx, supperenvy,'-')
plt.plot(slowerenvx, slowerenvy,'-')
plt.plot(slowerenvx,slowerfit,'-')
plt.axis([-1,300,103,104.5])
plt.show()
# Out:
# Start: 45 Stop: 51
# guessy0 :103.962471312
# guessA: -0.614712237774
# guesstau: 987.546643827
# fit: y=103.985772506+-0.547978420036*exp(-x/525.298606956)
# covariance;[[  1.43600896e-04  -1.40001737e-04   1.77685762e-01]
#  [ -1.40001737e-04   8.40411002e-04   1.95773187e+00]
#  [  1.77685762e-01   1.95773187e+00   9.26152017e+03]]

# %%
values = slurpfilebytesasarray("/home/jonathan/git/GoodSymCrypt/Colin's new glasses.jpg")
x,y = rmsdevautocorr(values)
# Out:
# Reading file: /home/jonathan/git/GoodSymCrypt/Colin's new glasses.jpg
# File size: 511217

# %%
supperenvx, supperenvy, slowerenvx, slowerenvy=smoothenv(x,y)
popt,cov = fit_to_line(slowerenvx[1:25], slowerenvy[1:25],verbose=True)
slowerfit = line_for_fit(slowerenvx,popt[0],popt[1])
popt,cov = fit_to_line(supperenvx[1:25], supperenvy[1:25],verbose=True)
supperfit = line_for_fit(supperenvx,popt[0],popt[1])
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(supperenvx, supperenvy,'-')
plt.plot(supperenvx,supperfit,'.')
plt.plot(slowerenvx, slowerenvy,'-')
plt.plot(slowerenvx,slowerfit,'.')
plt.axis([-1,300,103,104.5])
plt.show()
# Out:
# Start: 20 Stop: 23
# bguess :103.481161397
# mguess: 0.00111478261666
# fit: y=103.454488636+0.000759588168212*x
# covariance:
# [[  6.15036311e-04  -3.81787221e-06]
#  [ -3.81787221e-06   3.09871043e-08]]
# Start: 20 Stop: 23
# bguess :103.669397314
# mguess: -2.09047225478e-05
# fit: y=103.802570915+9.06082056023e-05*x
# covariance:
# [[  7.75978308e-04  -2.56555118e-07]
#  [ -2.56555118e-07   7.77148316e-10]]

# %%
values = slurpfilebytesasarray('/home/jonathan/git/GoodSymCrypt/test_vg.ecr')
x,y = rmsdevautocorr(values)
# Out:
# Reading file: /home/jonathan/git/GoodSymCrypt/test_vg.ecr
# File size: 67968

# %%
import matplotlib.pyplot as plt
supperenvx, supperenvy, slowerenvx, slowerenvy=smoothenv(x,y)
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(supperenvx, supperenvy,'-')
plt.plot(slowerenvx, slowerenvy,'-')
plt.axis([-1,250,103,104.5])
plt.show()

# %%
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(supperenvx, supperenvy,'-')
plt.plot(slowerenvx, slowerenvy,'-')
plt.axis([-1,max(slowerenvx),103,104.5])
plt.show()

# %%
popt,cov = fit_to_line(slowerenvx[1:25], slowerenvy[1:25],verbose=True)
slowerfit = line_for_fit(slowerenvx,popt[0],popt[1])
popt,cov = fit_to_line(supperenvx[1:25], supperenvy[1:25],verbose=True)
supperfit = line_for_fit(supperenvx,popt[0],popt[1])
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(supperenvx, supperenvy,'-')
plt.plot(supperenvx,supperfit,'.')
plt.plot(slowerenvx, slowerenvy,'-')
plt.plot(slowerenvx,slowerfit,'.')
plt.axis([-1,300,103,104.5])
plt.show()
# Out:
# Start: 20 Stop: 23
# bguess :103.393608828
# mguess: -0.00155206177961
# fit: y=103.342246932+-0.000500001476408*x
# covariance:
# [[  1.95934604e-03  -1.20471175e-05]
#  [ -1.20471175e-05   1.01699379e-07]]
# Start: 20 Stop: 23
# bguess :103.706582848
# mguess: 0.000165586078493
# fit: y=103.898688919+0.000401413305937*x
# covariance:
# [[  2.93912915e-03  -2.25059946e-05]
#  [ -2.25059946e-05   2.40812227e-07]]

# %%
values = slurpfilebytesasarray('/home/jonathan/git/GoodSymCrypt/glasses_rndpng.ecr')
x,y = rmsdevautocorr(values)
# Out:
# Reading file: /home/jonathan/git/GoodSymCrypt/glasses_rndpng.ecr
# File size: 1022524

# %%
supperenvx, supperenvy, slowerenvx, slowerenvy=smoothenv(x,y)
popt,cov = fit_to_line(slowerenvx[1:25], slowerenvy[1:25],verbose=True)
slowerfit = line_for_fit(slowerenvx,popt[0],popt[1])
popt,cov = fit_to_line(supperenvx[1:25], supperenvy[1:25],verbose=True)
supperfit = line_for_fit(supperenvx,popt[0],popt[1])
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(supperenvx, supperenvy,'-')
plt.plot(supperenvx,supperfit,'.')
plt.plot(slowerenvx, slowerenvy,'-')
plt.plot(slowerenvx,slowerfit,'.')
plt.axis([-1,300,104.6,105.2])
plt.show()
# Out:
# Start: 20 Stop: 23
# bguess :104.839351189
# mguess: -0.000872598282171
# fit: y=104.855340063+-0.000272445218686*x
# covariance:
# [[  2.75666078e-04  -1.70283829e-06]
#  [ -1.70283829e-06   1.36911518e-08]]
# Start: 20 Stop: 23
# bguess :105.006871844
# mguess: -0.00043028032057
# fit: y=104.98971406+-9.60312863483e-05*x
# covariance:
# [[  1.62311551e-04  -1.37126765e-06]
#  [ -1.37126765e-06   1.47911574e-08]]

# %%
popt,cov = fit_to_line(x[1:25], y[1:25],verbose=True)
fitA = line_for_fit(x,popt[0],popt[1])
popt,cov = fit_to_line(x[26:50],y[26:50],verbose=True)
fitB = line_for_fit(x,popt[0],popt[1])
popt,cov = fit_to_line(x[51:100],y[51:100],verbose=True)
fitC = line_for_fit(x,popt[0],popt[1])
popt,cov = fit_to_line(x[101:150],y[101:150],verbose=True)
fitD = line_for_fit(x,popt[0],popt[1])
popt,cov = fit_to_line(x[151:200],y[151:200],verbose=True)
fitE = line_for_fit(x,popt[0],popt[1])
plt.plot(x,y,'.')
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(x, fitA,'-',label='fitA')
plt.plot(x,fitB,'.',label='fitB')
plt.plot(x, fitC,'-',label='fitC')
plt.plot(x,fitD,'.',label='fitD')
plt.plot(x,fitE,'.',label='fitE')
plt.legend()
plt.axis([-1,300,104.6,105.2])
plt.show()
# Out:
# Start: 20 Stop: 23
# bguess :104.988764322
# mguess: -0.00425257948885
# fit: y=104.976662068+-0.00246301920824*x
# covariance:
# [[  5.19613326e-04  -3.18130452e-05]
#  [ -3.18130452e-05   2.54504640e-06]]
# Start: 20 Stop: 23
# bguess :104.834049577
# mguess: 0.000335180991603
# fit: y=104.889288056+0.000494855714739*x
# covariance:
# [[  2.45909257e-03  -6.34151136e-05]
#  [ -6.34151136e-05   1.69107121e-06]]
# Start: 43 Stop: 48
# bguess :104.941609046
# mguess: -0.000652288522335
# fit: y=104.978282494+-0.00102068796947*x
# covariance:
# [[  1.43013197e-03  -1.84137205e-05]
#  [ -1.84137205e-05   2.45516351e-07]]
# Start: 43 Stop: 48
# bguess :104.950566076
# mguess: -0.000301983921426
# fit: y=104.859122221+0.000396175433009*x
# covariance:
# [[  3.54931300e-03  -2.80356444e-05]
#  [ -2.80356444e-05   2.24285139e-07]]
# Start: 43 Stop: 48
# bguess :105.017801381
# mguess: -0.000466367184026
# fit: y=104.949675938+-0.000251340371873*x
# covariance:
# ...

# %%
upperenvx, upperenvy, lowerenvx, lowerenvy=envelope(x,y)
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(upperenvx,upperenvy,'-',label='upper envelope')
plt.plot(lowerenvx,lowerenvy,'-',label='lower envelope')
plt.legend()
plt.axis([-1,260,104.7,105.1])
plt.show()

# %%
print(str(np.mean(upperenvy[1:])))
print (str(np.mean(lowerenvy[1:])))
# Out:
# 104.954266334
# 104.865938811

# %%
print(str(np.mean(upperenvy[50:100])))
print (str(np.mean(lowerenvy[50:100])))
# Out:
# 104.956161799
# 104.859355605

# %%
print (str(upperenvx[10]))
print(str(np.mean(upperenvy[1:10])))
print (str(np.mean(lowerenvy[1:10])))
# Out:
# 30.0
# 104.991120802
# 104.888748014

# %%
print (str(x[10]))
print(str(np.mean(y[1:10])))
# Out:
# 10
# 104.958907867
# 104.958907867

# %%
values = slurpfilebytesasarray("/home/jonathan/git/GoodSymCrypt/Colin's new glasses.jpg")
x,y = rmsdevautocorr(values)
# Out:
# Reading file: /home/jonathan/git/GoodSymCrypt/Colin's new glasses.jpg
# File size: 511217

# %%
upperenvx, upperenvy, lowerenvx, lowerenvy=envelope(x,y)
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(upperenvx,upperenvy,'-',label='upper envelope')
plt.plot(lowerenvx,lowerenvy,'-',label='lower envelope')
plt.legend()
plt.axis([-1,260,103,104.5])
plt.show()

# %%
print(str(np.mean(upperenvy[1:])))
print (str(np.mean(lowerenvy[1:])))
# Out:
# 103.951350824
# 103.818685479

# %%
print(str(np.mean(upperenvy[50:100])))
print (str(np.mean(lowerenvy[50:100])))
# Out:
# 103.894184011
# 103.786031563

# %%
print (str(upperenvx[50]))
print(str(np.mean(upperenvy[1:50])))
print (str(np.mean(lowerenvy[1:50])))
# Out:
# 162.0
# 103.740750891
# 103.563287241

# %%
print (str(upperenvx[75]))
print(str(np.mean(upperenvy[1:75])))
print (str(np.mean(lowerenvy[1:75])))
# Out:
# 239.0
# 103.742856384
# 103.588724614

# %%
print (str(x[75]))
print(str(np.mean(y[1:75])))
# Out:
# 75
# 103.599555446

# %%
print (str(x[255]))
print(str(np.mean(y[1:255])))
# Out:
# 255
# 103.675199062

# %%
testfile=open('veryordered.dat','wb')
bytes=b''
for i in range(0,100):
    for k in range (0,256):
        bytes+=k.to_bytes(1,byteorder='big')
    for k in range (256,0):
        bytes+=k.to_bytes(1,byteorder='big')
testfile.write(bytes)
testfile.close()

# %%
values = slurpfilebytesasarray("veryordered.dat")
x,y = rmsdevautocorr(values)
# Out:
# Reading file: veryordered.dat
# File size: 25600

# %%
import matplotlib.pyplot as plt
upperenvx, upperenvy, lowerenvx, lowerenvy=envelope(x,y)
plt.ylabel('rmsdev')
plt.xlabel('offset')
plt.plot(x,y,'.',label='rmsdev')
plt.plot(upperenvx,upperenvy,'-',label='upper envelope')
plt.plot(lowerenvx,lowerenvy,'-',label='lower envelope')
plt.legend()
plt.axis([-1,2048,0,156])
plt.show()

# %%
print(str(np.mean(upperenvy[1:])))
print (str(np.mean(lowerenvy[1:])))
# Out:
# 124.726739187
# 55.6356915219

# %%
print(str(np.mean(y[1:])))
# Out:
# 100.648949
